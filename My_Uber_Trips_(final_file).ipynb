# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
#Updated csv file where missing values in 'Purpose' column got deleted.
uber_df = pd.read_csv("Uber_trips_2016.csv", low_memory=False)
uber_df
# Out:
#          START_DATE        END_DATE  CATEGORY            START   Latitude  \
# 0      1/2/16 20:25    1/2/16 20:38  Business      Fort Pierce  27.446706
# 1      1/5/16 17:31    1/5/16 17:45  Business      Fort Pierce  27.446706
# 2      1/6/16 14:42    1/6/16 15:49  Business      Fort Pierce  27.446706
# 3      1/6/16 17:15    1/6/16 17:19  Business  West Palm Beach  26.715342
# 4      1/6/16 17:30    1/6/16 17:35  Business  West Palm Beach  26.715342
# ..              ...             ...       ...              ...        ...
# 566  12/30/16 16:45  12/30/16 17:08  Business           Karchi  24.860734
# 567  12/30/16 23:06  12/30/16 23:10  Business           Karchi  24.860734
# 568   12/31/16 1:07   12/31/16 1:14  Business           Karchi  24.860734
# 569  12/31/16 21:32  12/31/16 21:50  Business       Katunayake   7.172485
# 570  12/31/16 22:08  12/31/16 23:51  Business          Gampaha   7.084048
#
#      Longitude             STOP  Latitude.1  Longitude.1  MILES  \
# 0   -80.325606      Fort Pierce   27.446706   -80.325606    4.8
# 1   -80.325606      Fort Pierce   27.446706   -80.325606    4.7
# 2   -80.325606  West Palm Beach   26.715342   -80.053375   63.7
# 3   -80.053375  West Palm Beach   26.715342   -80.053375    4.3
# 4   -80.053375       Palm Beach   26.705621   -80.036430    7.1
# ..         ...              ...         ...          ...    ...
# 566  67.001136           Karchi   24.860734    67.001136    4.6
# 567  67.001136           Karchi   24.860734    67.001136    0.8
# 568  67.001136           Karchi   24.860734    67.001136    0.7
# 569  79.885348          Gampaha    7.084048    80.009831    6.4
# 570  80.009831        Ilukwatta    7.259522    80.545234   48.2
#
#              PURPOSE    SALARY
# 0    Errand/Supplies   $10.32
# 1            Meeting   $10.11
# 2     Customer Visit  $136.96
# 3     Meal/Entertain    $9.25
# 4            Meeting   $15.27
# ..               ...       ...
# 566          Meeting    $9.89
# 567   Customer Visit    $1.72
# 568          Meeting    $1.51
# 569   Temporary Site   $13.76
# 570   Temporary Site  $103.63
#
# [571 rows x 12 columns]

# %%
from datetime import datetime

# %%
uber_df['START_DATE'] = pd.to_datetime(uber_df['START_DATE'], format = '%m/%d/%y %H:%M')
uber_df['END_DATE'] = pd.to_datetime(uber_df['END_DATE'], format = '%m/%d/%y %H:%M')

uber_df
# Out:
#              START_DATE            END_DATE  CATEGORY            START  \
# 0   2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 1   2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 2   2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 3   2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 4   2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
# ..                  ...                 ...       ...              ...
# 566 2016-12-30 16:45:00 2016-12-30 17:08:00  Business           Karchi
# 567 2016-12-30 23:06:00 2016-12-30 23:10:00  Business           Karchi
# 568 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Karchi
# 569 2016-12-31 21:32:00 2016-12-31 21:50:00  Business       Katunayake
# 570 2016-12-31 22:08:00 2016-12-31 23:51:00  Business          Gampaha
#
#       Latitude  Longitude             STOP  Latitude.1  Longitude.1  MILES  \
# 0    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.8
# 1    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.7
# 2    27.446706 -80.325606  West Palm Beach   26.715342   -80.053375   63.7
# 3    26.715342 -80.053375  West Palm Beach   26.715342   -80.053375    4.3
# 4    26.715342 -80.053375       Palm Beach   26.705621   -80.036430    7.1
# ..         ...        ...              ...         ...          ...    ...
# 566  24.860734  67.001136           Karchi   24.860734    67.001136    4.6
# 567  24.860734  67.001136           Karchi   24.860734    67.001136    0.8
# 568  24.860734  67.001136           Karchi   24.860734    67.001136    0.7
# 569   7.172485  79.885348          Gampaha    7.084048    80.009831    6.4
# 570   7.084048  80.009831        Ilukwatta    7.259522    80.545234   48.2
#
#              PURPOSE    SALARY
# 0    Errand/Supplies   $10.32
# 1            Meeting   $10.11
# 2     Customer Visit  $136.96
# 3     Meal/Entertain    $9.25
# 4            Meeting   $15.27
# ..               ...       ...
# 566          Meeting    $9.89
# 567   Customer Visit    $1.72
# 568          Meeting    $1.51
# 569   Temporary Site   $13.76
# 570   Temporary Site  $103.63
#
# [571 rows x 12 columns]

# %%
uber_df['MONTH'] = uber_df['START_DATE'].apply(lambda time: time.month)
uber_df['DAY_OF_THE_WEEK'] = uber_df['START_DATE'].apply(lambda time: time.dayofweek)

# %%
mmap = {1:'Jan', 2:'Feb',3:'Mar', 4:'Apr',5:'May',6:'June',7:'July', 8:'Aug', 9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
uber_df['MONTH'] = uber_df['MONTH'].map(mmap)
uber_df['MONTH']
# Out:
# 0      Jan
# 1      Jan
# 2      Jan
# 3      Jan
# 4      Jan
#       ...
# 566    Dec
# 567    Dec
# 568    Dec
# 569    Dec
# 570    Dec
# Name: MONTH, Length: 571, dtype: object

# %%
uber_df['DAY_OF_THE_WEEK'] = uber_df.START_DATE.dt.weekday
day_label = {
    0: 'Mon', 1: 'Tues', 2: 'Wed', 3: 'Thus', 4: 'Fri', 5: 'Sat', 6: 'Sun'
}
uber_df['DAY_OF_THE_WEEK'] = uber_df['DAY_OF_THE_WEEK'].map(day_label)
uber_df
# Out:
#              START_DATE            END_DATE  CATEGORY            START  \
# 0   2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 1   2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 2   2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 3   2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 4   2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
# ..                  ...                 ...       ...              ...
# 566 2016-12-30 16:45:00 2016-12-30 17:08:00  Business           Karchi
# 567 2016-12-30 23:06:00 2016-12-30 23:10:00  Business           Karchi
# 568 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Karchi
# 569 2016-12-31 21:32:00 2016-12-31 21:50:00  Business       Katunayake
# 570 2016-12-31 22:08:00 2016-12-31 23:51:00  Business          Gampaha
#
#       Latitude  Longitude             STOP  Latitude.1  Longitude.1  MILES  \
# 0    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.8
# 1    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.7
# 2    27.446706 -80.325606  West Palm Beach   26.715342   -80.053375   63.7
# 3    26.715342 -80.053375  West Palm Beach   26.715342   -80.053375    4.3
# 4    26.715342 -80.053375       Palm Beach   26.705621   -80.036430    7.1
# ..         ...        ...              ...         ...          ...    ...
# 566  24.860734  67.001136           Karchi   24.860734    67.001136    4.6
# 567  24.860734  67.001136           Karchi   24.860734    67.001136    0.8
# 568  24.860734  67.001136           Karchi   24.860734    67.001136    0.7
# 569   7.172485  79.885348          Gampaha    7.084048    80.009831    6.4
# 570   7.084048  80.009831        Ilukwatta    7.259522    80.545234   48.2
#
#              PURPOSE    SALARY MONTH DAY_OF_THE_WEEK
# 0    Errand/Supplies   $10.32    Jan             Sat
# 1            Meeting   $10.11    Jan            Tues
# 2     Customer Visit  $136.96    Jan             Wed
# 3     Meal/Entertain    $9.25    Jan             Wed
# 4            Meeting   $15.27    Jan             Wed
# ..               ...       ...   ...             ...
# 566          Meeting    $9.89    Dec             Fri
# 567   Customer Visit    $1.72    Dec             Fri
# 568          Meeting    $1.51    Dec             Sat
# 569   Temporary Site   $13.76    Dec             Sat
# 570   Temporary Site  $103.63    Dec             Sat
#
# [571 rows x 14 columns]

# %%
#Calculating duration of each ride
uber_df['DURATION'] = uber_df['END_DATE'] - uber_df['START_DATE']
uber_df.dtypes
# Out:
# START_DATE          datetime64[ns]
# END_DATE            datetime64[ns]
# CATEGORY                    object
# START                       object
# Latitude                   float64
# Longitude                  float64
# STOP                        object
# Latitude.1                 float64
# Longitude.1                float64
# MILES                      float64
# PURPOSE                     object
# SALARY                      object
# MONTH                       object
# DAY_OF_THE_WEEK             object
# DURATION           timedelta64[ns]
# dtype: object

# %%
uber_df
# Out:
#              START_DATE            END_DATE  CATEGORY            START  \
# 0   2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 1   2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 2   2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 3   2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 4   2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
# ..                  ...                 ...       ...              ...
# 566 2016-12-30 16:45:00 2016-12-30 17:08:00  Business           Karchi
# 567 2016-12-30 23:06:00 2016-12-30 23:10:00  Business           Karchi
# 568 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Karchi
# 569 2016-12-31 21:32:00 2016-12-31 21:50:00  Business       Katunayake
# 570 2016-12-31 22:08:00 2016-12-31 23:51:00  Business          Gampaha
#
#       Latitude  Longitude             STOP  Latitude.1  Longitude.1  MILES  \
# 0    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.8
# 1    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.7
# 2    27.446706 -80.325606  West Palm Beach   26.715342   -80.053375   63.7
# 3    26.715342 -80.053375  West Palm Beach   26.715342   -80.053375    4.3
# 4    26.715342 -80.053375       Palm Beach   26.705621   -80.036430    7.1
# ..         ...        ...              ...         ...          ...    ...
# 566  24.860734  67.001136           Karchi   24.860734    67.001136    4.6
# 567  24.860734  67.001136           Karchi   24.860734    67.001136    0.8
# 568  24.860734  67.001136           Karchi   24.860734    67.001136    0.7
# 569   7.172485  79.885348          Gampaha    7.084048    80.009831    6.4
# 570   7.084048  80.009831        Ilukwatta    7.259522    80.545234   48.2
#
#              PURPOSE    SALARY MONTH DAY_OF_THE_WEEK        DURATION
# 0    Errand/Supplies   $10.32    Jan             Sat 0 days 00:13:00
# 1            Meeting   $10.11    Jan            Tues 0 days 00:14:00
# 2     Customer Visit  $136.96    Jan             Wed 0 days 01:07:00
# 3     Meal/Entertain    $9.25    Jan             Wed 0 days 00:04:00
# 4            Meeting   $15.27    Jan             Wed 0 days 00:05:00
# ..               ...       ...   ...             ...             ...
# 566          Meeting    $9.89    Dec             Fri 0 days 00:23:00
# 567   Customer Visit    $1.72    Dec             Fri 0 days 00:04:00
# 568          Meeting    $1.51    Dec             Sat 0 days 00:07:00
# 569   Temporary Site   $13.76    Dec             Sat 0 days 00:18:00
# 570   Temporary Site  $103.63    Dec             Sat 0 days 01:43:00
#
# [571 rows x 15 columns]

# %%
uber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   START_DATE       571 non-null    datetime64[ns]
#  1   END_DATE         571 non-null    datetime64[ns]
#  2   CATEGORY         571 non-null    object
#  3   START            571 non-null    object
#  4   Latitude         544 non-null    float64
#  5   Longitude        544 non-null    float64
#  6   STOP             571 non-null    object
#  7   Latitude.1       543 non-null    float64
#  8   Longitude.1      543 non-null    float64
#  9   MILES            571 non-null    float64
#  10  PURPOSE          571 non-null    object
#  11  SALARY           571 non-null    object
#  12  MONTH            571 non-null    object
#  13  DAY_OF_THE_WEEK  571 non-null    object
#  14  DURATION         571 non-null    timedelta64[ns]
# dtypes: datetime64[ns](2), float64(5), object(7), timedelta64[ns](1)
# memory usage: 67.0+ KB

# %%
uber_df.describe()
# Out:
#          Latitude   Longitude  Latitude.1  Longitude.1       MILES  \
# count  544.000000  544.000000  543.000000   543.000000  571.000000
# mean    36.203147  -60.382207   36.598016   -60.158453   11.248862
# std     10.550109   51.831178    9.513798    51.345376   24.123120
# min    -37.845644 -122.419415  -32.046759  -122.935139    0.500000
# 25%     35.746230  -78.898619   35.738208   -78.898619    3.100000
# 50%     35.791540  -78.781117   35.791540   -78.781117    6.200000
# 75%     40.707348  -75.640182   40.714522   -75.640182   10.400000
# max     57.204617  144.076842   57.204617   115.912701  310.300000
#
#                         DURATION
# count                        571
# mean   0 days 00:22:31.313485113
# std    0 days 00:25:47.681069465
# min              0 days 00:02:00
# 25%              0 days 00:11:00
# 50%              0 days 00:17:00
# 75%              0 days 00:25:00
# max              0 days 05:30:00

# %%
uber_df.notnull().sum()
# Out:
# START_DATE         571
# END_DATE           571
# CATEGORY           571
# START              571
# Latitude           544
# Longitude          544
# STOP               571
# Latitude.1         543
# Longitude.1        543
# MILES              571
# PURPOSE            571
# SALARY             571
# MONTH              571
# DAY_OF_THE_WEEK    571
# DURATION           571
# dtype: int64

# %%
uber_df['CATEGORY'].unique()
# Out:
# array(['Business', 'Personal'], dtype=object)

# %%
sum(uber_df['CATEGORY']=='Business')
# Out:
# 565

# %%
sum(uber_df['CATEGORY']=='Personal')
# Out:
# 6

# %%
uber_total_count = uber_df.groupby(['CATEGORY']).sum()['MILES']
uber_total_count
# Out:
# CATEGORY
# Business    6209.6
# Personal     213.5
# Name: MILES, dtype: float64

# %%
sns.countplot(x=uber_df['CATEGORY']);

# %%
uber_df['PURPOSE'].unique()
# Out:
# array(['Errand/Supplies', 'Meeting', 'Customer Visit', 'Meal/Entertain',
#        'Temporary Site', 'Between Offices', 'Charity ($)', 'Commute',
#        'Moving', 'Airport/Travel'], dtype=object)

# %%
sum(uber_df['PURPOSE']=='Errand/Supplies')
# Out:
# 111

# %%
sum(uber_df['PURPOSE']=='Meeting')
# Out:
# 164

# %%
sum(uber_df['PURPOSE']=='Customer Visit')
# Out:
# 92

# %%
sum(uber_df['PURPOSE']=='Meal/Entertain')
# Out:
# 147

# %%
sum(uber_df['PURPOSE']=='Temporary Site')
# Out:
# 32

# %%
sum(uber_df['PURPOSE']=='Between Offices')
# Out:
# 18

# %%
sum(uber_df['PURPOSE']=='Charity ($)')
# Out:
# 1

# %%
sum(uber_df['PURPOSE']=='Commute')
# Out:
# 1

# %%
sum(uber_df['PURPOSE']=='Moving')
# Out:
# 4

# %%
sum(uber_df['PURPOSE']=='Airport/Travel')
# Out:
# 1

# %%
uber_ride_count = uber_df.groupby(['PURPOSE']).sum()['MILES']
uber_ride_count
# Out:
# PURPOSE
# Airport/Travel        4.1
# Between Offices     197.0
# Charity ($)          15.1
# Commute             180.2
# Customer Visit     1995.2
# Errand/Supplies     430.9
# Meal/Entertain      819.2
# Meeting            2435.2
# Moving               18.2
# Temporary Site      328.0
# Name: MILES, dtype: float64

# %%
purpose_labels = uber_df.PURPOSE.value_counts().nlargest(10)
sns.barplot(x=purpose_labels.index, y=purpose_labels);
plt.ylabel('Total Rides');
plt.xticks(rotation=90);

# %%
uber_df['MILES'].sum()
# Out:
# 6423.1

# %%
uber_df['DURATION'].sum()
# Out:
# Timedelta('8 days 22:20:00')

# %%
#salary column (Total)
uber_df.dtypes
# Out:
# START_DATE          datetime64[ns]
# END_DATE            datetime64[ns]
# CATEGORY                    object
# START                       object
# Latitude                   float64
# Longitude                  float64
# STOP                        object
# Latitude.1                 float64
# Longitude.1                float64
# MILES                      float64
# PURPOSE                     object
# SALARY                      object
# MONTH                       object
# DAY_OF_THE_WEEK             object
# DURATION           timedelta64[ns]
# dtype: object

# %%
uber_df['money_regex'] = uber_df['SALARY'].str.replace('[\$\,]','', regex = True)
uber_df['money_regex'] = pd.to_numeric(uber_df['money_regex'])
uber_df['money_regex']
# Out:
# 0       10.32
# 1       10.11
# 2      136.96
# 3        9.25
# 4       15.27
#         ...
# 566      9.89
# 567      1.72
# 568      1.51
# 569     13.76
# 570    103.63
# Name: money_regex, Length: 571, dtype: float64

# %%
uber_df
# Out:
#              START_DATE            END_DATE  CATEGORY            START  \
# 0   2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 1   2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 2   2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 3   2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 4   2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
# ..                  ...                 ...       ...              ...
# 566 2016-12-30 16:45:00 2016-12-30 17:08:00  Business           Karchi
# 567 2016-12-30 23:06:00 2016-12-30 23:10:00  Business           Karchi
# 568 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Karchi
# 569 2016-12-31 21:32:00 2016-12-31 21:50:00  Business       Katunayake
# 570 2016-12-31 22:08:00 2016-12-31 23:51:00  Business          Gampaha
#
#       Latitude  Longitude             STOP  Latitude.1  Longitude.1  MILES  \
# 0    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.8
# 1    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.7
# 2    27.446706 -80.325606  West Palm Beach   26.715342   -80.053375   63.7
# 3    26.715342 -80.053375  West Palm Beach   26.715342   -80.053375    4.3
# 4    26.715342 -80.053375       Palm Beach   26.705621   -80.036430    7.1
# ..         ...        ...              ...         ...          ...    ...
# 566  24.860734  67.001136           Karchi   24.860734    67.001136    4.6
# 567  24.860734  67.001136           Karchi   24.860734    67.001136    0.8
# 568  24.860734  67.001136           Karchi   24.860734    67.001136    0.7
# 569   7.172485  79.885348          Gampaha    7.084048    80.009831    6.4
# 570   7.084048  80.009831        Ilukwatta    7.259522    80.545234   48.2
#
#              PURPOSE    SALARY MONTH DAY_OF_THE_WEEK        DURATION  \
# 0    Errand/Supplies   $10.32    Jan             Sat 0 days 00:13:00
# 1            Meeting   $10.11    Jan            Tues 0 days 00:14:00
# 2     Customer Visit  $136.96    Jan             Wed 0 days 01:07:00
# 3     Meal/Entertain    $9.25    Jan             Wed 0 days 00:04:00
# 4            Meeting   $15.27    Jan             Wed 0 days 00:05:00
# ..               ...       ...   ...             ...             ...
# 566          Meeting    $9.89    Dec             Fri 0 days 00:23:00
# 567   Customer Visit    $1.72    Dec             Fri 0 days 00:04:00
# 568          Meeting    $1.51    Dec             Sat 0 days 00:07:00
# 569   Temporary Site   $13.76    Dec             Sat 0 days 00:18:00
# 570   Temporary Site  $103.63    Dec             Sat 0 days 01:43:00
#
#      money_regex
# 0          10.32
# 1          10.11
# 2         136.96
# 3           9.25
# 4          15.27
# ..           ...
# 566         9.89
# 567         1.72
# 568         1.51
# 569        13.76
# 570       103.63
#
# [571 rows x 16 columns]

# %%
uber_df['money_regex'].sum()
# Out:
# 13811.189999999999

# %%
start_labels = uber_df.START.value_counts().nlargest(10)
sns.set(style='darkgrid')
sns.barplot(x=start_labels.index, y=start_labels);
plt.ylabel('Value Counts');
plt.xticks(rotation=90);

# %%
sns.countplot(x=uber_df['MONTH']);
sns.set(style='darkgrid')

# %%
miles_dic = {}
for i in uber_df.MILES:
    if i < 10:
        if '0-10 miles' not in miles_dic:
            miles_dic['0-10 miles'] = [i]
        else:
            miles_dic['0-10 miles'].append(i)
            
    elif i >= 10 and i < 20:
        if '10-20 miles' not in miles_dic:
            miles_dic['10-20 miles'] = [i]
        else:
            miles_dic['10-20 miles'].append(i)
    
    elif i >= 20 and i < 30:
        if '20-30 miles' not in miles_dic:
            miles_dic['20-30 miles'] = [i]
        else:
            miles_dic['20-30 miles'].append(i)
            
    elif i >= 30 and i < 40:
        if '30-40 miles' not in miles_dic:
            miles_dic['30-40 miles'] = [i]
        else:
            miles_dic['30-40 miles'].append(i)
            
    elif i >= 40 and i < 50:
        if '40-50 miles' not in miles_dic:
            miles_dic['40-50 miles'] = [i]
        else:
            miles_dic['40-50 miles'].append(i)
    else:
        if 'Above 50 miles' not in miles_dic:
            miles_dic['Above 50 miles'] = [i]
        else:
            miles_dic['Above 50 miles'].append(i)

# %%
len_miles = []
for key in miles_dic:
    len_miles.append((key, len(miles_dic[key])))
a, b = [], []
for i, j in len_miles:
    a.append(i)
    b.append(j)
plt.figure(figsize=(10, 5))
plt.xticks(rotation=0)
sns.barplot(x=a, y=b)
plt.xlabel('Miles')
plt.ylabel('Count');

# %%
sns.countplot(hue='CATEGORY', x='DAY_OF_THE_WEEK', data=uber_df);
sns.set(style='ticks')

# %%
sns.countplot(hue='PURPOSE', x='MONTH', data=uber_df);
sns.set(style='whitegrid')

# %%
uber_df
# Out:
#              START_DATE            END_DATE  CATEGORY            START  \
# 0   2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 1   2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 2   2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 3   2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 4   2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
# ..                  ...                 ...       ...              ...
# 566 2016-12-30 16:45:00 2016-12-30 17:08:00  Business           Karchi
# 567 2016-12-30 23:06:00 2016-12-30 23:10:00  Business           Karchi
# 568 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Karchi
# 569 2016-12-31 21:32:00 2016-12-31 21:50:00  Business       Katunayake
# 570 2016-12-31 22:08:00 2016-12-31 23:51:00  Business          Gampaha
#
#       Latitude  Longitude             STOP  Latitude.1  Longitude.1  MILES  \
# 0    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.8
# 1    27.446706 -80.325606      Fort Pierce   27.446706   -80.325606    4.7
# 2    27.446706 -80.325606  West Palm Beach   26.715342   -80.053375   63.7
# 3    26.715342 -80.053375  West Palm Beach   26.715342   -80.053375    4.3
# 4    26.715342 -80.053375       Palm Beach   26.705621   -80.036430    7.1
# ..         ...        ...              ...         ...          ...    ...
# 566  24.860734  67.001136           Karchi   24.860734    67.001136    4.6
# 567  24.860734  67.001136           Karchi   24.860734    67.001136    0.8
# 568  24.860734  67.001136           Karchi   24.860734    67.001136    0.7
# 569   7.172485  79.885348          Gampaha    7.084048    80.009831    6.4
# 570   7.084048  80.009831        Ilukwatta    7.259522    80.545234   48.2
#
#              PURPOSE    SALARY MONTH DAY_OF_THE_WEEK        DURATION  \
# 0    Errand/Supplies   $10.32    Jan             Sat 0 days 00:13:00
# 1            Meeting   $10.11    Jan            Tues 0 days 00:14:00
# 2     Customer Visit  $136.96    Jan             Wed 0 days 01:07:00
# 3     Meal/Entertain    $9.25    Jan             Wed 0 days 00:04:00
# 4            Meeting   $15.27    Jan             Wed 0 days 00:05:00
# ..               ...       ...   ...             ...             ...
# 566          Meeting    $9.89    Dec             Fri 0 days 00:23:00
# 567   Customer Visit    $1.72    Dec             Fri 0 days 00:04:00
# 568          Meeting    $1.51    Dec             Sat 0 days 00:07:00
# 569   Temporary Site   $13.76    Dec             Sat 0 days 00:18:00
# 570   Temporary Site  $103.63    Dec             Sat 0 days 01:43:00
#
#      money_regex
# 0          10.32
# 1          10.11
# 2         136.96
# 3           9.25
# 4          15.27
# ..           ...
# 566         9.89
# 567         1.72
# 568         1.51
# 569        13.76
# 570       103.63
#
# [571 rows x 16 columns]

# %%
uber_df.to_csv("My_Uber_Trips_(final_file).csv", index=False)

# %%
uber_df.to_json(r'/Users/markpalkovskyi/Desktop/UC Davis/Final Project/Final_project/My_Uber_Trips_(final_file).json')

# %%
uber_df.to_excel(r'/Users/markpalkovskyi/Desktop/UC Davis/Final Project/Final_project/My_Uber_Trips_(final_file).xlsx')
